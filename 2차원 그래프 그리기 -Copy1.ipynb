# %%
# 준비물 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#데이터 작성
np.random.seed(1) #난수를 고정하겠습니다.
x = np.arange(10)
y = np.random.rand(10)

#그래프 출력
plt.plot(x,y)
plt.show()
